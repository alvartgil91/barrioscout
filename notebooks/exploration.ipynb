# %% [markdown]
# # BarrioScout — Exploratory Analysis
#
# Use this notebook to explore raw data from each source before building production ingestion scripts.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import requests
from config.settings import CITIES, OVERPASS_URL

# %%
# Example: fetch hospitals in Granada
from src.ingestion.osm_pois import extract, transform

raw = extract(CITIES['granada']['bbox'], category='health')
df = transform(raw, city='granada', category='health')
df.head()
